# %%
# !pip install tensorflow keras numpy matplotlib scikit-learn
# !pip install lifelines
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 11.3 MB/s eta 0:00:00
# ...
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4030 sha256=e73bde2b2f95739a43966f89fe6b3b566ae1e8d32ad043036321e1cba6041ac2
#   Stored in directory: /root/.cache/pip/wheels/50/37/21/0a719b9d89c635e89ff24bd93b862882ad675279552013b2fb
# Successfully built autograd-gamma
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# /content/drive/MyDrive/Drug-Target-Binding-Affinity/DeepDTA_Meshari/source/
fpath = '/content/drive/MyDrive/Kd_Meshari/'

# %%
# %cd '/content/drive/MyDrive/Kd_Meshari/'
# Out:
# /content/drive/MyDrive/Kd_Meshari

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Kd_Meshari

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Aug 18 12:47:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             48W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install -U cupy-cuda12x
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 MB 22.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 13.3.0
#     Uninstalling cupy-cuda12x-13.3.0:
#       Successfully uninstalled cupy-cuda12x-13.3.0
# ...

# %%
import cupy as cp

# Create and test a GPU array
a = cp.asarray([1, 2, 3])
print("GPU array:", a)
print("Device:", a.device)
# Out:
# GPU array: [1 2 3]
# Device: <CUDA Device 0>

# %%
import xgboost
print(xgboost.__version__)
# Out:
# 3.0.4

# %%
# !python3 --version
# Out:
# Python 3.11.13

# %%
# !pip install torch torchvision tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 127.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# kiba_run_experiments_Meshari22_parallel.py
# kiba_run_1
# kiba_run_experiments_Meshari22_parallel_55.py
# kiba_run_experiments_XGB_Tuning.py
# kiba_run_experiments_CNN
# kiba_run_experiments_active_learning.py
# !python3 Kiba_run_experiments_Meshari_final.py --num_windows 32 \
                          --seq_window_lengths 8 \
                          --smi_window_lengths 4 \
                          --batch_size 256 \
                          --num_epoch 2 \
                          --max_seq_len 1000 \
                          --max_smi_len 100 \
                          --dataset_path 'data/kiba/' \
                          --problem_type 1 \
                          --log_dir 'logs/'
# Out:
# total 39558
# drwx------ 3 root root     4096 Jun 21 00:52 affinity2vec
# -rw------- 1 root root     2797 Aug 17 18:59 arguments1.py
# -rw------- 1 root root     2797 Jun 15 18:05 arguments.py
# -rw------- 1 root root    10869 Jun 13 22:45 auc.jar
# drwx------ 2 root root     4096 Aug 23 21:44 aupr_davis
# drwx------ 2 root root     4096 Aug 23 22:01 aupr_kiba
# -rw------- 1 root root 27313686 Aug 18 22:38 best_diffusion_model.pt
# -rw------- 1 root root   799692 Jun 25 07:19 best_lstm_model.pt
# drwx------ 2 root root     4096 Aug  1 16:04 code
# drwx------ 3 root root     4096 Jun 13 21:19 data
# -rw------- 1 root root     5507 Jun 19 04:23 datahelper.py
# -rw------- 1 root root    17027 Aug 23 22:05 Davis_DeepDTA_Execution2.ipynb
# -rw------- 1 root root    27358 Aug 23 22:03 Davis_run_experiments_Meshari22.py
# -rw------- 1 root root    21301 Aug 17 19:08 DeepDTA_Execution2.ipynb
# -rw------- 1 root root     2095 Jun 13 22:48 emetrics.py
# ...
